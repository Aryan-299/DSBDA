# %%
import pandas as pd

# %%
df = pd.read_csv("dataset_Facebook.csv", sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df1=df[['Page total likes', 'Category','Post Month','Post Weekday']].loc[0:15]
df1
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 1             139441         2          12             3
# 2             139441         3          12             3
# 3             139441         2          12             2
# 4             139441         2          12             2
# 5             139441         2          12             1
# 6             139441         3          12             1
# 7             139441         3          12             7
# 8             139441         2          12             7
# 9             139441         3          12             6
# 10            139441         2          12             5
# 11            139441         2          12             5
# 12            139441         2          12             5
# 13            139441         2          12             5
# 14            138414         2          12             4
# ...

# %%
df2=df[['Page total likes', 'Category','Post Month','Post Weekday']].loc[16:30]
df2
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 16            138414         3          12             3
# 17            138414         1          12             2
# 18            138414         3          12             2
# 19            138414         3          12             1
# 20            138414         2          12             1
# 21            138414         1          12             7
# 22            138414         1          12             7
# 23            138414         3          12             7
# 24            138414         2          12             6
# 25            138458         2          12             6
# 26            138458         2          12             5
# 27            138458         3          12             5
# 28            138895         2          12             5
# 29            138895         1          12             4
# 30            138895         2          12             4

# %%
df3=df[['Page total likes', 'Category','Post Month','Post Weekday']].loc[30:45]
df3
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 30            138895         2          12             4
# 31            138895         2          12             3
# 32            138895         3          12             3
# 33            138895         3          12             2
# 34            138895         1          12             2
# 35            138895         2          12             1
# 36            138895         3          12             1
# 37            138895         1          12             7
# 38            138895         2          12             7
# 39            138895         1          12             7
# 40            138895         2          12             6
# 41            138895         1          12             6
# 42            138353         1          12             5
# 43            138353         1          12             5
# 44            138353         1          12             4
# ...

# %%
merging=pd.concat([df1,df2,df3])
merging
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 1             139441         2          12             3
# 2             139441         3          12             3
# 3             139441         2          12             2
# 4             139441         2          12             2
# 5             139441         2          12             1
# 6             139441         3          12             1
# 7             139441         3          12             7
# 8             139441         2          12             7
# 9             139441         3          12             6
# 10            139441         2          12             5
# 11            139441         2          12             5
# 12            139441         2          12             5
# 13            139441         2          12             5
# 14            138414         2          12             4
# ...

# %%
merging2=pd.concat([df2,df3])
merging2
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 16            138414         3          12             3
# 17            138414         1          12             2
# 18            138414         3          12             2
# 19            138414         3          12             1
# 20            138414         2          12             1
# 21            138414         1          12             7
# 22            138414         1          12             7
# 23            138414         3          12             7
# 24            138414         2          12             6
# 25            138458         2          12             6
# 26            138458         2          12             5
# 27            138458         3          12             5
# 28            138895         2          12             5
# 29            138895         1          12             4
# 30            138895         2          12             4
# ...

# %%
sort_values=merging.sort_values('Page total likes', ascending=False)
sort_values
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 8             139441         2          12             7
# 1             139441         2          12             3
# 13            139441         2          12             5
# 12            139441         2          12             5
# 11            139441         2          12             5
# 9             139441         3          12             6
# 10            139441         2          12             5
# 7             139441         3          12             7
# 6             139441         3          12             1
# 5             139441         2          12             1
# 4             139441         2          12             2
# 3             139441         2          12             2
# 2             139441         3          12             3
# 34            138895         1          12             2
# ...

# %%
sort_values.transpose()
# Out:
#                       0       8       1       13      12      11      9   \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Category               2       2       2       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       7       3       5       5       5       6
#
#                       10      7       6   ...      19      18      17      16  \
# Page total likes  139441  139441  139441  ...  138414  138414  138414  138414
# Category               2       3       3  ...       3       3       1       3
# Post Month            12      12      12  ...      12      12      12      12
# Post Weekday           5       7       1  ...       1       2       2       3
#
#                       15      14      42      43      44      45
# Page total likes  138414  138414  138353  138353  138353  138353
# Category               2       2       1       1       1       1
# ...

# %%
sort_values
# Out:
#     Page total likes  Category  Post Month  Post Weekday
# 0             139441         2          12             4
# 8             139441         2          12             7
# 1             139441         2          12             3
# 13            139441         2          12             5
# 12            139441         2          12             5
# 11            139441         2          12             5
# 9             139441         3          12             6
# 10            139441         2          12             5
# 7             139441         3          12             7
# 6             139441         3          12             1
# 5             139441         2          12             1
# 4             139441         2          12             2
# 3             139441         2          12             2
# 2             139441         3          12             3
# 34            138895         1          12             2
# ...

# %%
shaping=df.shape
shaping
# Out:
# (500, 19)

# %%
pivot_t=pd.pivot_table(df , index=["Type","Category"], values='like')
pivot_t
# Out:
#                        like
# Type   Category
# Link   1          75.650000
#        2          32.000000
#        3          68.000000
# Photo  1         126.000000
#        2         235.857143
#        3         219.753333
# Status 1         136.333333
#        2         182.552632
#        3         151.500000
# Video  1         231.428571

# %%
sort_values.plot()
# Out:
# <Axes: >
